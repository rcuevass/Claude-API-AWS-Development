# %% [markdown]
# # Basic Amazon Bedrock Streaming Example

# %%
from utils.azn_bedrock_multiturn_chat import azn_streaming_messages

# %%
generated_msg = azn_streaming_messages("Write a 1 sentence description of a fake database",
                                       print_event=False, loop_over_stream=False)
# Out:
# ...
# Here is a one sentence description of a fake database:
#
# **"CustomerVault Pro is a fictional relational database containing 50,000 simulated customer records, including made-up names, addresses, purchase histories, and account details, used for software testing and demonstration purposes."**

# %%
generated_msg
# Out:
# '\n\nTotal Message:\nHere is a one sentence description of a fake database:\n\n**"CustomerVault Pro is a fictional relational database containing 50,000 simulated customer records, including made-up names, addresses, purchase histories, and account details, used for software testing and demonstration purposes."**'

# %%
print(generated_msg)
# Out:
# Total Message:
# Here is a one sentence description of a fake database:
#
# **"CustomerVault Pro is a fictional relational database containing 50,000 simulated customer records, including made-up names, addresses, purchase histories, and account details, used for software testing and demonstration purposes."**
