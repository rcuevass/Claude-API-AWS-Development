# %% [markdown]
# # Simple example of chat with system prompt

# %%
from utils.multiturn_chat import add_user_message, add_assistant_message, chat

# %%
messages = []

# %%
add_user_message(messages, "Write a Python function that chceks a string for duplicate characters")

# %%
system_prompt = "You are a software engineer with vast experience in Python, who writes very concise code"

# %%
answer = chat(messages, system_prompt = system_prompt)

# %%
print(answer)
# Out:
# ```python
# def has_duplicates(s: str) -> bool:
#     return len(s) != len(set(s))
# ```
#
# **Example usage:**
# ```python
# print(has_duplicates("hello"))   # True  ('l' appears twice)
# print(has_duplicates("world"))   # False
# print(has_duplicates("python"))  # False
# ```
#
# If you also want to **identify** the duplicate characters:
#
# ```python
# def find_duplicates(s: str) -> set:
#     seen = set()
#     return {c for c in s if c in seen or seen.add(c)}
#
# print(find_duplicates("hello world"))  # {'l', 'o'}
# ```
