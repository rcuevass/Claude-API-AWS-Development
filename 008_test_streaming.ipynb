# %% [markdown]
# # Basic streaming test

# %%
from utils.multiturn_chat import streaming_messages

# %%
events_stored = streaming_messages("Write 1 sentence description of a fake database", print_message=True)
# Out:
# Here is a one sentence description of a fake database:
#
# **"NovaBase"** is a fictional cloud-based relational database management system that stores and organizes data across distributed servers using a proprietary query language called NQL (NovaBase Query Language).

# %%
events_stored
# Out:
# ParsedMessage(id='msg_011Cd6ishPjcsrr88uEXuzkF', container=None, content=[ParsedTextBlock(citations=None, text='Here is a one sentence description of a fake database:\n\n**"NovaBase"** is a fictional cloud-based relational database management system that stores and organizes data across distributed servers using a proprietary query language called NQL (NovaBase Query Language).', type='text', parsed_output=None)], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=17, output_tokens=60, output_tokens_details=None, server_tool_use=None, service_tier='standard'))
