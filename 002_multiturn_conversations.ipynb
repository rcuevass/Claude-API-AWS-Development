# %% [markdown]
# # Multi-Turn Conversations

# %% [markdown]
# Make sure the env variables are available

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# Create an API client and make a request. Make sure to check the models available in Claude API console

# %%
# Create an API client
from anthropic import Anthropic

# %%
client = Anthropic()
model_selected = "claude-sonnet-4-6"

# %% [markdown]
# Creating auxiliary functions

# %%
def add_user_message(messages: list, text: str) -> None:
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

# %%
def add_assistant_message(messages: list, text: str) -> None:
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

# %%
def chat(messages: list(str)):
    # Make a request
    message = client.messages.create(
        model=model_selected, # model selected by user, setup in cell above
        max_tokens=1000, # max budget on number of tokens that Claude can generate. 
        messages=[
            {
                "role": "user", 
                "content": "Whats is quantume computing? Answer in one sentence"
            }
                ] # List of messages, user message in this case
)

# %%
# Make a request
message = client.messages.create(
    model=model_selected, # model selected by user, setup in cell above
    max_tokens=1000, # max budget on number of tokens that Claude can generate. 
    messages=[
        {
            "role": "user", 
            "content": "Whats is quantume computing? Answer in one sentence"
        }
    ] # List of messages, user message in this case
)

# %% [markdown]
# Display the response from the model selected

# %%
message
# Out:
# Message(id='msg_01ARHjjtqcTHjpxnPVB6Whp2', container=None, content=[TextBlock(citations=None, text='Quantum computing is a type of computing that uses quantum mechanical phenomena, such as **superposition** and **entanglement**, to process information in ways that classical computers cannot, enabling much faster solutions to certain complex problems.', type='text')], model='claude-sonnet-4-6', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=19, output_tokens=48, output_tokens_details=None, server_tool_use=None, service_tier='standard'))

# %%
message.content[0].text
# Out:
# 'Quantum computing is a type of computing that uses quantum mechanical phenomena, such as **superposition** and **entanglement**, to process information in ways that classical computers cannot, enabling much faster solutions to certain complex problems.'
