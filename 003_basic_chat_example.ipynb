# %% [markdown]
# # Simple interactive chat example

# %%
from utils.multiturn_chat import trigger_interactive_chat

# %%
# invoke this function, captured under utils module
trigger_interactive_chat()
